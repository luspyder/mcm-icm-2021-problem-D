# %%
import pandas as pd

# %%
data=pd.read_csv('6feature after std.csv')

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.head()
# Out:
#     emotion    rhythm    purity  duration_ms  popularity  instrumentalness  \
# 0  0.167738  0.550364  0.496426     0.113372        0.54          0.585586
# 1  0.170781  0.510836  0.465361     0.151105        0.53          0.148148
# 2  0.293203  0.591077  0.360774     0.111822        0.55          0.345345
# 3  0.863037  0.454809  0.516557     0.078535        0.34          0.000031
# 4  0.585052  0.491941  0.503528     0.068173        0.37          0.000001
#
#         genre  year
# 0  Electronic  2005
# 1  Electronic  2005
# 2  Electronic  2009
# 3        R&B;  1991
# 4        R&B;  1987

# %% [markdown]
# # 单指标多领域变化

# %%
data['genre'].unique()
# Out:
# array(['Electronic', 'R&B;', 'Vocal', 'Pop/Rock', 'Religious', 'Blues',
#        'Country', nan, 'Jazz', 'Latin', 'New Age', 'Folk',
#        'International', 'Reggae', 'Comedy/Spoken', 'Easy Listening',
#        'Classical', 'Avant-Garde', 'Stage & Screen', "Children's",
#        'Unknown'], dtype=object)

# %%
data1=data[data['genre']=='Electronic']

# %%
data1['rhythm'].hist()

# %%
data1.groupby('year').agg('mean')['popularity'].values.tolist()
# Out:
# [0.0,
#  0.0009090909090909091,
#  0.16,
#  0.0,
#  0.28500000000000003,
#  0.28,
#  0.308,
#  0.3066666666666667,
#  0.355,
#  0.3516666666666666,
#  0.3235294117647059,
#  0.37249999999999994,
#  0.35733333333333334,
#  0.4077777777777778,
#  0.33368421052631575,
#  0.2966666666666667,
#  0.34125000000000005,
#  0.33999999999999997,
#  0.4025,
#  0.287,
#  0.395,
#  0.45,
#  0.48166666666666674,
#  0.47388888888888897,
#  0.47800000000000004,
#  0.457142857142857,
#  0.45827586206896537,
#  0.4603125,
#  0.4640909090909091,
#  0.4777966101694913,
#  0.47400000000000003,
#  0.4488059701492538,
#  0.471875,
#  0.4534285714285713,
#  0.5357142857142856,
#  0.47411764705882353,
#  0.518125,
#  0.4931578947368421,
#  0.4932,
#  0.5337209302325582,
#  0.5102941176470589,
#  0.4900000000000001,
#  0.4982142857142858,
#  0.49439999999999995,
#  0.5488709677419358,
#  0.5931578947368421,
#  0.6008888888888888,
#  0.6034210526315789,
#  0.6157894736842107,
#  0.6351219512195123,
# ...

# %% [markdown]
# # 单领域多指标变化

# %%
data['genre'].unique()
# Out:
# array(['Electronic', 'R&B;', 'Vocal', 'Pop/Rock', 'Religious', 'Blues',
#        'Country', nan, 'Jazz', 'Latin', 'New Age', 'Folk',
#        'International', 'Reggae', 'Comedy/Spoken', 'Easy Listening',
#        'Classical', 'Avant-Garde', 'Stage & Screen', "Children's",
#        'Unknown'], dtype=object)

# %% [markdown]
# ## R&B

# %%
after=data[data['genre']=='R&B;'].groupby(by=['year']).mean()
after.index#1949年之前的删除
# Out:
# Int64Index([1927, 1932, 1936, 1941, 1942, 1947, 1949, 1950, 1951, 1952, 1953,
#             1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#             1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#             1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#             1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#             1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#             2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#             2020],
#            dtype='int64', name='year')

# %%
after.drop([1927, 1932, 1936, 1941, 1942, 1947],inplace=True)

# %%
after.columns
# Out:
# Index(['emotion', 'rhythm', 'purity', 'duration_ms', 'popularity',
#        'instrumentalness'],
#       dtype='object')

# %%
after=data[data['genre']=='R&B;'].groupby(by=['year']).mean()
for i in after.columns:
    after[i].plot(legend=True,figsize=(10,7))

# %%
after.index
# Out:
# Int64Index([1927, 1932, 1936, 1941, 1942, 1947, 1949, 1950, 1951, 1952, 1953,
#             1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#             1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#             1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#             1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#             1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#             2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#             2020],
#            dtype='int64', name='year')

# %%
after.drop([1927, 1932, 1936, 1941, 1942, 1947],inplace=True)
for i in after.columns:
    after[i].plot(legend=True,figsize=(10,7))

# %%
after=data[data['genre']=='Vocal'].groupby(by=['year']).mean()
for i in after.columns:
    after[i].plot(legend=True,figsize=(10,7))

# %%
after=data[data['genre']=='Pop/Rock'].groupby(by=['year']).mean()
for i in after.columns:
    after[i].plot(legend=True,figsize=(10,7))

# %%
after.index
# Out:
# Int64Index([1925, 1930, 1938, 1941, 1942, 1945, 1947, 1949, 1951, 1954, 1955,
#             1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966,
#             1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,
#             1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#             1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#             2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#             2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
#            dtype='int64', name='year')

# %%
after.drop([1925, 1930, 1938, 1941, 1942, 1945, 1947, 1949, 1951],inplace=True)
for i in after.columns:
    after[i].plot(legend=True,figsize=(10,7))

# %%
after=data[data['genre']=='Country'].groupby(by=['year']).mean()
for i in after.columns:
    after[i].plot(legend=True,figsize=(10,7))

# %%
after.index
# Out:
# Int64Index([1930, 1935, 1936, 1937, 1938, 1941, 1945, 1946, 1947, 1949, 1950,
#             1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961,
#             1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972,
#             1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#             1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
#             1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#             2017, 2018, 2019, 2020],
#            dtype='int64', name='year')

# %%
after.drop([1930, 1935, 1936, 1937, 1938, 1941, 1945, 1946, 1947],inplace=True)
for i in after.columns:
    after[i].plot(legend=True,figsize=(10,7))

# %%
after=data[data['genre']=='Latin'].groupby(by=['year']).mean()
for i in after.columns:
    after[i].plot(legend=True,figsize=(10,7))

# %%
after.index
# Out:
# Int64Index([1939, 1941, 1944, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953,
#             1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964,
#             1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#             1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#             1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#             1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#             2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#             2020],
#            dtype='int64', name='year')

# %%
after.drop([1939, 1941, 1944, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953,
            1954, 1955,],inplace=True)
for i in after.columns:
    after[i].plot(legend=True,figsize=(10,7))

# %%
for i in feature6_by_field.iterrows():
    print(i[1].values.tolist()[1:])
# Out:
# [1.33, 38.89, 1.59, 212581.3, 23.98, 0.2, 1964.56]
# [1.87, 41.09, 1.41, 216722.18, 23.3, 0.08, 1965.15]
# [2.0, 42.18, 1.38, 129730.8, 23.57, 0.01, 1973.79]
# [1.27, 36.41, 1.74, 288746.1, 12.58, 0.51, 1957.66]
# [1.81, 36.53, 1.18, 218990.09, 22.61, 0.0, 1974.8]
# [2.03, 41.9, 1.28, 194508.4, 35.87, 0.03, 1984.54]
# [1.46, 38.62, 1.53, 179973.91, 18.44, 0.53, 1961.31]
# [1.62, 41.82, 1.03, 280763.77, 50.87, 0.35, 2001.99]
# [1.6, 40.13, 1.57, 195383.4, 24.21, 0.07, 1968.21]
# [1.75, 40.46, 1.49, 261695.24, 20.71, 0.16, 1966.96]
# [1.41, 39.16, 1.54, 306111.89, 21.04, 0.39, 1962.88]
# [1.9, 41.74, 1.29, 225522.88, 42.53, 0.04, 1986.92]
# [1.11, 38.18, 1.71, 290956.96, 37.48, 0.71, 1988.35]
# [1.92, 43.15, 1.04, 239647.61, 40.92, 0.09, 1987.07]
# [1.78, 40.79, 1.16, 247040.91, 39.83, 0.03, 1985.55]
# [1.88, 40.73, 1.09, 241471.27, 36.74, 0.1, 1980.09]
# [1.87, 42.26, 1.1, 264423.01, 41.76, 0.01, 1998.0]
# [1.19, 35.76, 1.58, 210351.06, 29.82, 0.49, 1977.78]
# ...

# %%
for i in feature6_by_field.iterrows():
    print(i[1].values[0])
# Out:
# Avant-Garde
# Blues
# Children's
# Classical
# Comedy/Spoken
# Country
# Easy Listening
# Electronic
# Folk
# International
# Jazz
# Latin
# New Age
# Pop/Rock
# R&B;
# Reggae
# Religious
# Stage & Screen
# Unknown
# Vocal

# %%
["Children's", 2.0, 42.18, 1.38, 129730.8, 23.57, 0.01, 1973.79]
['Classical', 1.27, 36.41, 1.74, 288746.1, 12.58, 0.51, 1957.66]
['Easy Listening', 1.46, 38.62, 1.53, 179973.91, 18.44, 0.53, 1961.31]
['Electronic', 1.62, 41.82, 1.03, 280763.77, 50.87, 0.35, 2001.99]
['International', 1.75, 40.46, 1.49, 261695.24, 20.71, 0.16, 1966.96]
['Jazz', 1.41, 39.16, 1.54, 306111.89, 21.04, 0.39, 1962.88]
['Latin', 1.9, 41.74, 1.29, 225522.88, 42.53, 0.04, 1986.92]
['New Age', 1.11, 38.18, 1.71, 290956.96, 37.48, 0.71, 1988.35]
['Stage & Screen', 1.19, 35.76, 1.58, 210351.06, 29.82, 0.49, 1977.78]
['Unknown', 2.4, 42.35, 1.01, 207280.0, 41.62, 0.01, 1991.62]

# %% [markdown]
# Avant-Garde
# Children's
# Classical
# Easy Listening
# Electronic
# International
# Jazz
# Latin
# New Age
# Stage & Screen
# Unknown

# %%
# 类1
option = {
    title: {
        text: ''
    },
    tooltip: {},
    legend: {
        data: ['Blues','Comedy/Spoken','Country','Folk','Pop/Rock','R&B;','Reggae','Religious','Vocal']
    },
    radar: {
        // shape: 'circle',
        name: {
            textStyle: {
                color: '#fff',
                backgroundColor: '#999',
                borderRadius: 3,
                padding: [3, 5]
            }
        },
        indicator: [
                 {text: 'emotion', max: 2.5},
                {text: 'rhythm', max: 60},
                {text: 'purity', max: 2},
                {text: 'duration_ms', max: 310000},
                {text: 'popularity', max: 60},
                {text: 'instrumentalness', max: 0.8},
        ]
    },
    series: [{
        name: '预算 vs 开销（Budget vs spending）',
        type: 'radar',
        // areaStyle: {normal: {}},
        data: [
            {
                value: [1.67 ,39.09, 1.35, 216722.18 ,23.3, 0.08,1965.15],
                name: 'Blues'
            },
            {
                value: [1.61, 36.53, 1.28, 218990.09, 22.61, 0.0, 1974.8],
                name: 'Comedy/Spoken'
            },
                        {
                value: [1.73, 39.9, 1.28, 194508.4, 35.87, 0.03, 1984.54],
                name: 'Country'
            },            {
                value:[ 1.6, 37.13, 1.27, 195383.4, 24.21, 0.07, 1968.21],
                name: 'Folk'
            },                      {
                value: [1.59, 38.16, 1.21, 191296.33, 20.85, 0.02, 1959.31]
,
                name: 'Vocal'
            },
        ]
    }]
};

# %%
option = {
    title: {
        text: ''
    },
    tooltip: {},
    legend: {
        data: ['Blues','Comedy/Spoken','Country','Folk','Pop/Rock','R&B;','Reggae','Religious','Vocal','Latin']
    },
    radar: {
        // shape: 'circle',
        name: {
            textStyle: {
                color: '#fff',
                backgroundColor: '#999',
                borderRadius: 3,
                padding: [3, 5]
            }
        },
        indicator: [
                 {text: 'emotion', max: 2.5},
                {text: 'rhythm', max: 60},
                {text: 'purity', max: 2},
                {text: 'duration_ms', max: 310000},
                {text: 'popularity', max: 60},
                {text: 'instrumentalness', max: 0.8},
        ]
    },
    series: [{
        name: '预算 vs 开销（Budget vs spending）',
        type: 'radar',
        // areaStyle: {normal: {}},
        data: [
            {
                value:  [ 1.92, 43.15, 1.04, 239647.61, 40.92, 0.09, 1987.07],
                name: 'Pop/Rock'
            },            {
                value: [1.78, 40.79, 1.16, 247040.91, 39.83, 0.03, 1985.55],
                name: 'R&B;'
            },            {
                value: [1.88, 40.73, 1.09, 241471.27, 36.74, 0.1, 1980.09],
                name: 'Reggae'
            },            {
                value:  [1.87, 42.26, 1.1, 264423.01, 41.76, 0.01, 1998.0]
,
                name: 'Religious'
            },  
            {
                value:  [ 1.9, 41.74, 1.29, 225522.88, 42.53, 0.04, 1986.92]
,
                name: 'Latin',
            },  
        ]
    }]
};

# %%
#第三类
option = {
    title: {
        text: ''
    },
    tooltip: {},
    legend: {
        data: ['Easy Listening','Stage & Screen']
    },
    radar: {
        // shape: 'circle',
        name: {
            textStyle: {
                color: '#fff',
                backgroundColor: '#999',
                borderRadius: 3,
                padding: [3, 5]
            }
        },
        indicator: [
                 {text: 'emotion', max: 2.5},
                {text: 'rhythm', max: 60},
                {text: 'purity', max: 2},
                {text: 'duration_ms', max: 310000},
                {text: 'popularity', max: 60},
                {text: 'instrumentalness', max: 0.8},
        ]
    },
    series: [{
        name: '预算 vs 开销（Budget vs spending）',
        type: 'radar',
        // areaStyle: {normal: {}},
        data: [
            {
                value: [ 1.46, 38.62, 1.53, 179973.91, 18.44, 0.53, 1961.31],
                name: 'Easy Listening',
            },
            {
                value: [ 1.19, 35.76, 1.58, 210351.06, 29.82, 0.49, 1977.78],
                name: 'Stage & Screen',
            },
                    
        ]
    }]
};

# %%
#杂类
option = {
    title: {
        text: '多雷达图'
    },
    tooltip: {
        trigger: 'axis'
    },
    legend: {
        height:'center',
        left: 'center',
        data:['Classical',  'Electronic', 'International', 'Jazz', 'New Age' ]
 
    },
    radar: [
        {
            indicator: [
                {text: 'emotion', max: 2.5},
                {text: 'rhythm', max: 60},
                {text: 'purity', max: 2},
                {text: 'duration_ms', max: 310000},
                {text: 'popularity', max: 60},
                {text: 'instrumentalness', max: 0.8},
            ],
            center: ['19%', '50%'],
            radius: 180
        },
        {
            indicator: [
                {text: 'emotion', max: 2.5},
                {text: 'rhythm', max: 60},
                {text: 'purity', max: 2},
                {text: 'duration_ms', max: 310000},
                {text: 'popularity', max: 60},
                {text: 'instrumentalness', max: 0.8},
            ],
            radius: 180,
            center: ['50%', '75%'],
        },
        {
            indicator: [
                {text: 'emotion', max: 2.5},
                {text: 'rhythm', max: 60},
                {text: 'purity', max: 2},
                {text: 'duration_ms', max: 310000},
                {text: 'popularity', max: 60},
                {text: 'instrumentalness', max: 0.8},
            ],
            center: ['81%', '50%'],
            radius: 180
        },
        {
            indicator: [
                {text: 'emotion', max: 2.5},
                {text: 'rhythm', max: 60},
                {text: 'purity', max: 2},
                {text: 'duration_ms', max: 310000},
                {text: 'popularity', max: 60},
                {text: 'instrumentalness', max: 0.8},
            ],
            center: ['50%', '25%'],
            radius: 180
        },
    ],
    series: [
        {
            type: 'radar',
            tooltip: {
                trigger: 'item'
            },
            areaStyle: {},
            data: [
                {
                value: [ 1.27, 36.41, 1.74, 288746.1, 12.58, 0.51, 1957.66],
                name: 'Classical',
                }
            ]
        },
        {
            type: 'radar',
            radarIndex: 1,
            areaStyle: {},
            data: [
                {
                value:[1.62, 41.82, 1.03, 280763.77, 50.87, 0.35, 2001.99],
                name: 'Electronic',
                },

                
            ]
        },
        {
            type: 'radar',
            radarIndex: 2,
            areaStyle: {},
            data: [
                {
                value: [ 1.75, 40.46, 1.49, 261695.24, 20.71, 0.16, 1966.96],
                name: 'International',
                },

            ]
        },
         {
            type: 'radar',
            radarIndex: 3,
            areaStyle: {},
            data: [
                {
                value:[ 1.41, 39.16, 1.54, 306111.89, 21.04, 0.39, 1962.88],
                name: 'Jazz',
                }
            ]
        },
    ]
};
