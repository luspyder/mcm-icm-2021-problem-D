# %%
import pandas as pd

# %%
data=pd.read_csv('../problem3 data/6feature after std.csv')
data.drop('Unnamed: 0',axis=1,inplace=True)
data.head()
# Out:
#     emotion    rhythm    purity  duration_ms  popularity  instrumentalness  \
# 0  0.167738  0.550364  0.496426     0.113372        0.54          0.585586
# 1  0.170781  0.510836  0.465361     0.151105        0.53          0.148148
# 2  0.293203  0.591077  0.360774     0.111822        0.55          0.345345
# 3  0.863037  0.454809  0.516557     0.078535        0.34          0.000031
# 4  0.585052  0.491941  0.503528     0.068173        0.37          0.000001
#
#         genre  year
# 0  Electronic  2005
# 1  Electronic  2005
# 2  Electronic  2009
# 3        R&B;  1991
# 4        R&B;  1987

# %%
for i in after.columns:
    print(i)
# Out:
# emotion
# rhythm
# purity
# duration_ms
# popularity
# instrumentalness

# %%
after=data[data['genre']=='R&B;'].groupby(by=['year']).mean()
for i in after.columns:
    after[i].plot(legend=True,figsize=(20,7),fontsize=15)

# %%
full_music_data=pd.read_csv('../problem3 data/full_music plus geners.csv')
full_music_data.drop('Unnamed: 0',axis=1,inplace=True)
full_music_data.head()
# Out:
#             artist_names  artists_id  danceability  energy  valence    tempo  \
# 0  ["Fat Freddy's Drop"]      178301         0.600   0.365    0.131  130.046
# 1  ["Fat Freddy's Drop"]      178301         0.874   0.326    0.179  119.620
# 2  ["Fat Freddy's Drop"]      178301         0.670   0.531    0.336  139.385
# 3   ["Alexander O'Neal"]      625201         0.761   0.702    0.850  104.773
# 4   ["Alexander O'Neal"]      625201         0.661   0.828    0.902  115.078
#
#    loudness  mode  key  acousticness  instrumentalness  liveness  speechiness  \
# 0   -13.083     0    9        0.0672          0.585000    0.0921       0.0498
# 1   -13.302     0   11        0.0136          0.148000    0.0993       0.1310
# 2    -8.267     0    9        0.0156          0.345000    0.3060       0.0377
# 3    -8.523     1    7        0.1080          0.000031    0.0935       0.0389
# 4   -12.673     0   11        0.2760          0.000001    0.2870       0.0390
#
# ...

# %%
rb_full_data=full_music_data[full_music_data['genre']=='R&B;']
rb_full_data.head()
# Out:
#            artist_names  artists_id  danceability  energy  valence    tempo  \
# 3  ["Alexander O'Neal"]      625201         0.761   0.702    0.850  104.773
# 4  ["Alexander O'Neal"]      625201         0.661   0.828    0.902  115.078
# 5  ["Alexander O'Neal"]      625201         0.719   0.650    0.953  105.141
# 6  ["Alexander O'Neal"]      625201         0.649   0.245    0.273  112.709
# 7  ["Alexander O'Neal"]      625201         0.701   0.715    0.735  101.515
#
#    loudness  mode  key  acousticness  instrumentalness  liveness  speechiness  \
# 3    -8.523     1    7        0.1080          0.000031    0.0935       0.0389
# 4   -12.673     0   11        0.2760          0.000001    0.2870       0.0390
# 5   -12.947     0    7        0.0103          0.000044    0.1330       0.0265
# 6   -17.585     1   11        0.4960          0.000000    0.1740       0.0286
# 7   -14.999     0   11        0.0600          0.000000    0.3540       0.0291
#
# ...

# %%
rb_mean_by_year=rb_full_data.groupby('year').mean()

# %%
rb_mean_by_year=rb_mean_by_year.loc[:,['danceability', 'energy', 'valence', 'tempo', 'loudness',
       'mode', 'key', 'acousticness', 'instrumentalness', 'liveness',
       'speechiness', 'explicit', 'duration_ms', 'popularity']]

# %%
#标准化
rb_mean_by_year.head()
# Out:
#       danceability  energy  valence    tempo  loudness  mode  key  \
# year
# 1927        0.6705  0.6420   0.8145  103.010  -11.2720   0.0  5.0
# 1936        0.6480  0.3560   0.5290   86.735  -13.9170   0.0  7.0
# 1941        0.5045  0.4275   0.2770  110.275   -7.3680   0.5  5.0
# 1942        0.5230  0.3730   0.4930   79.855  -12.9900   0.0  9.0
# 1947        0.4605  0.4195   0.5895  123.575  -11.7305   0.5  8.0
#
#       acousticness  instrumentalness  liveness  speechiness  explicit  \
# year
# 1927        0.6695          0.248400    0.1085      0.05035       0.0
# 1936        0.8960          0.000036    0.1100      0.08370       0.0
# 1941        0.7120          0.006500    0.1145      0.03190       0.0
# 1942        0.4460          0.000011    0.1030      0.09320       0.0
# 1947        0.7280          0.467018    0.4390      0.04230       0.0
#
#       duration_ms  popularity
# year
# 1927     153913.0         1.0
# 1936     186160.0         3.0
# 1941     240500.0         3.0
# ...

# %%
rb_mean_by_year['tempo'].hist()

# %%
rb_mean_by_year['loudness'].hist()

# %%
#以上两个指标需要做标准化之前的预处理，删除离群值
rb_mean_by_year[rb_mean_by_year['tempo']<90]
# Out:
#       danceability  energy  valence   tempo  loudness  mode  key  \
# year
# 1936         0.648   0.356    0.529  86.735   -13.917   0.0  7.0
# 1942         0.523   0.373    0.493  79.855   -12.990   0.0  9.0
#
#       acousticness  instrumentalness  liveness  speechiness  explicit  \
# year
# 1936         0.896          0.000036     0.110       0.0837       0.0
# 1942         0.446          0.000011     0.103       0.0932       0.0
#
#       duration_ms  popularity
# year
# 1936     186160.0         3.0
# 1942     124120.0        15.0

# %%
rb_mean_by_year.loc[[1936,1942],'tempo']=100

# %%
rb_mean_by_year[rb_mean_by_year['loudness']<-18]
# Out:
#       danceability  energy  valence    tempo  loudness  mode  key  \
# year
# 1955        0.4266  0.1006     0.35  104.872  -20.4864   0.8  6.2
#
#       acousticness  instrumentalness  liveness  speechiness  explicit  \
# year
# 1955        0.9674            0.1046    0.1802      0.14002       0.0
#
#       duration_ms  popularity
# year
# 1955     168389.4         0.0

# %%
rb_mean_by_year.loc[[1955],'loudness']=-14

# %%
std_data=rb_mean_by_year.loc[:,['tempo','loudness','key','duration_ms','popularity']]

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
std_data=min_max_scaler.fit_transform(std_data)

# %%
rb_mean_by_year[['tempo','loudness','key','duration_ms','popularity']]=std_data

# %% [markdown]
# ## 生成echarts用的数据

# %%
for i in rb_mean_by_year.columns:
    print(i)
    print(rb_mean_by_year.loc[:,i].values.tolist())
# Out:
# danceability
# ...

# %%
len(rb_mean_by_year.columns)
# Out:
# 14

# %%
j=0
for i in rb_mean_by_year.columns[0:3]:
        rb_mean_by_year[i].plot(legend=True,figsize=(10,7))

# %%
for i in rb_mean_by_year.columns[3:6]:
        rb_mean_by_year[i].plot(legend=True,figsize=(10,7))

# %%
for i in rb_mean_by_year.columns[6:9]:
        rb_mean_by_year[i].plot(legend=True,figsize=(10,7))

# %%
for i in rb_mean_by_year.columns[9:12]:
        rb_mean_by_year[i].plot(legend=True,figsize=(10,7))

# %%
for i in rb_mean_by_year.columns[12:]:
        rb_mean_by_year[i].plot(legend=True,figsize=(10,7))
